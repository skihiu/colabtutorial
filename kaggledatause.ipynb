# %% [markdown]
# <a href="https://colab.research.google.com/github/skihiu/colabtutorial/blob/master/kaggledatause.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # Create directories, list files
import os
os.environ['KAGGLE_CONFIG_DIR']='/content'
#Login to you Kaggle account. On settings, create New Api token and upload it to your content folder. Select on the specific data, in kaggle and click on 3 dots on you right and select on copy Api Command .
#The command will be as below depending on your selection.
# !kaggle competitions download -c titanic
# Out:
# ...
#   0% 0.00/34.1k [00:00<?, ?B/s]
# 100% 34.1k/34.1k [00:00<00:00, 27.2MB/s]

# %%
#Data will be available as zipped. Unzip it and rm the zip file
# !unzip \*.zip && rm *.zip
# Out:
# Archive:  titanic.zip
# replace gender_submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: gender_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
#import panda library and read the csv
import pandas as pd
df=pd.read_csv('train.csv')
df
df.head(90)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 85           86         1       3
# 86           87         0       3
# 87           88         0       3
# 88           89         1       1
# 89           90         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
#You can test with more data.
# !kaggle datasets download -d gpreda/life-expectancy-in-europe-by-age-and-sex
# Out:
# ...
#   0% 0.00/681k [00:00<?, ?B/s]
# 100% 681k/681k [00:00<00:00, 121MB/s]

# %%
# !unzip \*.zip && rm *.zip
# Out:
# Archive:  life-expectancy-in-europe-by-age-and-sex.zip
# replace demo_mlexpec.tsv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: demo_mlexpec.tsv
